# %%
# %cd /content/drive/MyDrive/Colab Notebooks/NLP/Mediqa/DoubleTransfer_MEDIQA2019-master
# Out:
# /content/drive/MyDrive/Colab Notebooks/NLP/Mediqa/DoubleTransfer_MEDIQA2019-master

# %%
# %cd ../bert_models
## DOWNLOAD BERT vocabulary
# !wget https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip -O "uncased_bert_base.zip"
# !unzip uncased_bert_base.zip
# !mv uncased_L-12_H-768_A-12/vocab.txt "../bert_models/"
# !rm *.zip
# !rm -rf uncased_L-12_H-768_A-12

## Download MT-DNN models
# !wget https://mrc.blob.core.windows.net/mt-dnn-model/mt_dnn_base.pt -O "../bert_models/mt_dnn_base.pt"
# !wget https://mrc.blob.core.windows.net/mt-dnn-model/mt_dnn_large.pt -O "../bert_models/mt_dnn_large.pt"

## Download SciBERT models
# !wget https://s3-us-west-2.amazonaws.com/ai2-s2-research/scibert/pytorch_models/scibert_scivocab_uncased.tar -O "uncased_scibert_base.tar"
# !tar -xvf uncased_scibert_base.tar
# Out:
# /content/drive/MyDrive/Colab Notebooks/NLP/Mediqa/bert_models
# --2021-03-24 01:31:41--  https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.217.128, 64.233.170.128, 108.177.12.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.217.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 407727028 (389M) [application/zip]
# Saving to: ‘uncased_bert_base.zip’
#
# uncased_bert_base.z 100%[===================>] 388.84M  42.8MB/s    in 8.9s
#
# 2021-03-24 01:31:50 (43.8 MB/s) - ‘uncased_bert_base.zip’ saved [407727028/407727028]
#
# Archive:  uncased_bert_base.zip
#    creating: uncased_L-12_H-768_A-12/
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.meta
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
#   inflating: uncased_L-12_H-768_A-12/vocab.txt
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/NLP/Mediqa/DoubleTransfer_MEDIQA2019-master
# Out:
# /content/drive/MyDrive/Colab Notebooks/NLP/Mediqa/DoubleTransfer_MEDIQA2019-master

# %%
# !pip install boto3
# Out:
# ...
#      |████████████████████████████████| 102kB 4.0MB/s
# ...
#      |████████████████████████████████| 7.3MB 5.5MB/s
# ...
#      |████████████████████████████████| 81kB 6.7MB/s
# ...
#      |████████████████████████████████| 153kB 39.4MB/s
# ...
#   Created wheel for boto3: filename=boto3-1.17.37-py2.py3-none-any.whl size=128780 sha256=7629bbc18c947a1658f217142a824696347f3511675bbf4a21a24c4a03768eb5
#   Stored in directory: /root/.cache/pip/wheels/01/66/72/f1bb0906ee42cd7ab67802dcb37fc3163ff34413a526553b7b
# Successfully built boto3
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.4 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# !python get_mediqa_gt.py
# Out:
# python3: can't open file 'get_mediqa_gt.py': [Errno 2] No such file or directory

# %%
# !python prepro_mediqa.py --med
# l.167: is_train à enlever
# l.181: commenter la ligne
# l.167 prepro_mediqa commentée
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# skip because none answer: 0000031-5 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0000031.xml
# skip because none answer: 0000031-6 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0000031.xml
# skip because none answer: 0003310-1 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-2 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-3 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-4 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-5 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-6 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-7 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-8 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# ...

# %%
# %cd /content/drive/MyDrive/NLP/new/transformers_maison
# !pip install .
# Out:
# /content/drive/MyDrive/NLP/new/transformers_maison
# Processing /content/drive/MyDrive/NLP/new/transformers_maison
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 890kB 4.2MB/s
# ...
#      |████████████████████████████████| 3.2MB 7.9MB/s
# ...
#      |████████████████████████████████| 133kB 36.2MB/s
# ...
#   Created wheel for transformers: filename=transformers-4.4.0.dev0-cp37-none-any.whl size=1923487 sha256=6639951c84624b9f8ff237e25e7133bb3beb67f635f56e76defb185a858d3d6c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f5yvqot3/wheels/e0/40/6b/912d164254490423ab97f37b8b12f227271de643e318dfd9cd
# Successfully built transformers
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=37910d72622ebb5ceb06907932ec479132b16e40f7ce3e0189baf82341bc9115
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/NLP/Mediqa/DoubleTransfer_MEDIQA2019-master
# !python prepro_mediqa.py --charac
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# skip because none answer: 0000031-5 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0000031.xml
# skip because none answer: 0000031-6 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0000031.xml
# skip because none answer: 0003310-1 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-2 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-3 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-4 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-5 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-6 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-7 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# skip because none answer: 0003310-8 ../data/mediqa/MedQuAD/10_MPlus_ADAM_QA 0003310.xml
# ...
