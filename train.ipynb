# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/NLP/Mediqa/DoubleTransfer_MEDIQA2019-master
# Out:
# /content/drive/MyDrive/Colab Notebooks/NLP/Mediqa/DoubleTransfer_MEDIQA2019-master

# %%
# !pip install boto3
# Out:
# ...
#      |████████████████████████████████| 102kB 10.1MB/s
# ...
#      |████████████████████████████████| 7.3MB 44.4MB/s
# ...
#      |████████████████████████████████| 81kB 11.4MB/s
# ...
#      |████████████████████████████████| 153kB 58.7MB/s
# ...
#   Created wheel for boto3: filename=boto3-1.17.37-py2.py3-none-any.whl size=128780 sha256=4127aadfd160f9376b39538bda1a7714ea81d7aabc4cf2e6fce1368939359a15
#   Stored in directory: /root/.cache/pip/wheels/01/66/72/f1bb0906ee42cd7ab67802dcb37fc3163ff34413a526553b7b
# Successfully built boto3
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.4 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# utils l.34/batcher l.145/model l.122: async changé en non_blocking
# !python train.py --train_datasets mednli,rqe,mediqa,medquad --save_last --mediqa_score adjusted --mediqa_score_offset -2.0 --batch_size 12 --max_seq_len 384 --data_dir ../data/mediqa_processed/mt_dnn_mediqa_384/ --init_checkpoint ../bert_models/mt_dnn_base.pt --float_medquad --external_datasets mnli --mtl_opt 0 --output_dir ../model_data/ --epochs 1
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.4) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# ...

# %%
import os

path = "/content/drive/MyDrive/NLP/new"

try:
    os.chdir(path)
    print("Current working directory: {0}".format(os.getcwd()))
except FileNotFoundError:
    print("Directory: {0} does not exist".format(path))
except NotADirectoryError:
    print("{0} is not a directory".format(path))
except PermissionError:
    print("You do not have permissions to change to {0}".format(path))
# Out:
# Current working directory: /content/drive/MyDrive/NLP/new

# %%
# %cd transformers_maison
# !pip install .
# %cd /content/drive/MyDrive/Colab Notebooks/NLP/Mediqa/DoubleTransfer_MEDIQA2019-master
# Out:
# /content/drive/MyDrive/NLP/new/transformers_maison
# Processing /content/drive/MyDrive/NLP/new/transformers_maison
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 3.2MB 18.8MB/s
# ...
#      |████████████████████████████████| 890kB 46.4MB/s
# ...
#      |████████████████████████████████| 133kB 54.9MB/s
# ...
#   Created wheel for transformers: filename=transformers-4.4.0.dev0-cp37-none-any.whl size=1923487 sha256=f1dc064091c25b0b2a4230947cbdff65fb6af3c32d1440bb0d5db8a8f6f03323
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3m2p39x2/wheels/e0/40/6b/912d164254490423ab97f37b8b12f227271de643e318dfd9cd
# Successfully built transformers
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=777d632f24c637d5016a163001cf1e55ea59141146bdb845e9dcc5f8cb492dbc
# ...

# %%
# !python train.py --train_datasets mednli,rqe,mediqa,medquad --save_last --mediqa_score adjusted --chr --mediqa_score_offset -2.0 --batch_size 4 --max_seq_len 384 --data_dir ../data/mediqa_processed/mt_dnn_mediqa_384_charac/ --init_checkpoint ../bert_models/mt_dnn_base.pt --float_medquad --external_datasets mnli --mtl_opt 0 --output_dir ../model_data/test2 --epochs 1
# Out:
# 2021-03-25 01:10:59.609780: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
from transformers import CharacterBertModel
import torch
import numpy as np
bert = CharacterBertModel.from_pretrained('/content/drive/MyDrive/NLP/new/character-bert/pretrained-models/general_character_bert/')#, is_decoder=True)
ids = np.array([[[261]*50]])
t = np.array([[0]])
out = bert(torch.from_numpy(ids), torch.from_numpy(t))

# %%
all_encoder_layers = out[0]
pooled_output = out[1]
all_encoder_layers, pooled_output
# Out:
# (tensor([[[-2.7671e-01, -2.3126e-02,  1.7800e-01,  3.8826e-01,  8.3948e-02,
#             6.1442e-02,  3.3964e-02,  1.1063e-01, -5.5818e-01,  4.7300e-01,
#             1.4287e-01,  5.4970e-01,  1.4920e-01,  5.7302e-01,  3.6511e-01,
#            -1.6211e-01,  2.5068e-01, -1.7589e-01,  1.5434e-02,  6.6801e-01,
#            -2.2996e-02, -9.5420e-02, -1.3029e-01, -1.9626e-01,  5.2959e-01,
#            -4.2278e-01,  8.7006e-02, -9.2337e-02, -1.6124e-01,  6.1270e-01,
#            -2.1449e-01, -1.9509e-01,  7.2387e-02, -5.1754e-01,  1.6028e-01,
#            -2.8945e-01, -2.9309e-01, -8.7318e-01, -1.0303e-01,  1.3200e+00,
#             6.6260e-01,  4.4501e-01,  2.8339e-01,  4.6875e-01, -2.4444e-01,
#            -6.5453e-02,  3.4547e-01,  4.4517e-01,  2.0880e-01,  6.7458e-01,
#            -1.3891e-01,  4.0024e-01,  4.8108e-01,  1.1887e-02,  6.9132e-02,
#            -1.3655e-01, -8.8718e-02,  1.1287e-01,  5.2700e-01, -4.6292e-03,
# ...

# %%
out
# Out:
# BaseModelOutputWithPoolingAndCrossAttentions([('last_hidden_state',
#                                                tensor([[[-2.7671e-01, -2.3126e-02,  1.7800e-01,  3.8826e-01,  8.3948e-02,
#                                                           6.1442e-02,  3.3964e-02,  1.1063e-01, -5.5818e-01,  4.7300e-01,
#                                                           1.4287e-01,  5.4970e-01,  1.4920e-01,  5.7302e-01,  3.6511e-01,
#                                                          -1.6211e-01,  2.5068e-01, -1.7589e-01,  1.5434e-02,  6.6801e-01,
#                                                          -2.2996e-02, -9.5420e-02, -1.3029e-01, -1.9626e-01,  5.2959e-01,
#                                                          -4.2278e-01,  8.7006e-02, -9.2337e-02, -1.6124e-01,  6.1270e-01,
#                                                          -2.1449e-01, -1.9509e-01,  7.2387e-02, -5.1754e-01,  1.6028e-01,
# ...

# %%
# !python train.py --train_datasets mednli,rqe,mediqa --save_last --mediqa_score adjusted --chr --mediqa_score_offset -2.0 --batch_size 16 --max_seq_len 384 --data_dir ../data/mediqa_processed/mt_dnn_mediqa_384_charac/ --init_checkpoint ../bert_models/mt_dnn_base.pt --float_medquad --mtl_opt 0 --output_dir ../model_data/test_char_1 --epochs 5
# Out:
# Namespace(answer_att_hidden_size=128, answer_att_type='bilinear', answer_dropout_p=0.1, answer_mem_drop_p=0.1, answer_mem_type=1, answer_merge_opt=1, answer_num_turn=5, answer_opt=0, answer_relu=False, answer_rnn_type='gru', answer_sum_att_type='bilinear', answer_weight_norm_on=False, batch_size=16, batch_size_eval=16, bert_dropout_p=0.1, bert_l2norm=0.0, chr=True, cuda=True, data_dir='../data/mediqa_processed/mt_dnn_mediqa_384_charac/', data_root='../data/', data_sort_on=False, dropout_p=0.1, dropout_w=0.0, dump_state_on=False, ema_gamma=0.995, ema_opt=0, embedding_opt=0, epochs=5, external_datasets=[], external_include_ratio=1.0, finetune=False, float_medquad=True, float_target=False, freeze_bert_first=False, freeze_layers=-1, global_grad_clipping=1.0, grad_clipping=0, have_lr_scheduler=True, hinge_lambda=1.0, init_checkpoint='../bert_models/mt_dnn_base.pt', init_config=None, init_ratio=1, label_size='3,3,2', learning_rate=5e-05, log_file='mt-dnn-train.log', log_per_updates=500, lr
# ...

# %%
# !python train.py --train_datasets mednli,rqe,mediqa --save_last --mediqa_score adjusted --chr --mediqa_score_offset -2.0 --batch_size 16 --max_seq_len 384 --data_dir ../data/mediqa_processed/mt_dnn_mediqa_384_charac/ --init_checkpoint ../bert_models/mt_dnn_base.pt --float_medquad --mtl_opt 0 --output_dir ../model_data/test_char_3 --epochs 5
# Out:
# Namespace(answer_att_hidden_size=128, answer_att_type='bilinear', answer_dropout_p=0.1, answer_mem_drop_p=0.1, answer_mem_type=1, answer_merge_opt=1, answer_num_turn=5, answer_opt=0, answer_relu=False, answer_rnn_type='gru', answer_sum_att_type='bilinear', answer_weight_norm_on=False, batch_size=16, batch_size_eval=16, bert_dropout_p=0.1, bert_l2norm=0.0, chr=True, cuda=True, data_dir='../data/mediqa_processed/mt_dnn_mediqa_384_charac/', data_root='../data/', data_sort_on=False, dropout_p=0.1, dropout_w=0.0, dump_state_on=False, ema_gamma=0.995, ema_opt=0, embedding_opt=0, epochs=5, external_datasets=[], external_include_ratio=1.0, finetune=False, float_medquad=True, float_target=False, freeze_bert_first=False, freeze_layers=-1, global_grad_clipping=1.0, grad_clipping=0, have_lr_scheduler=True, hinge_lambda=1.0, init_checkpoint='../bert_models/mt_dnn_base.pt', init_config=None, init_ratio=1, label_size='3,3,2', learning_rate=5e-05, log_file='mt-dnn-train.log', log_per_updates=500, lr
# ...

# %%
# !python train.py --train_datasets mednli,rqe,mediqa --save_last --mediqa_score adjusted --mediqa_score_offset -2.0 --batch_size 16 --max_seq_len 384 --data_dir ../data/mediqa_processed/mt_dnn_mediqa_384/ --init_checkpoint ../bert_models/mt_dnn_base.pt --float_medquad --mtl_opt 0 --output_dir ../model_data/test_bert_1 --epochs 5
# Out:
# Namespace(answer_att_hidden_size=128, answer_att_type='bilinear', answer_dropout_p=0.1, answer_mem_drop_p=0.1, answer_mem_type=1, answer_merge_opt=1, answer_num_turn=5, answer_opt=0, answer_relu=False, answer_rnn_type='gru', answer_sum_att_type='bilinear', answer_weight_norm_on=False, batch_size=16, batch_size_eval=16, bert_dropout_p=0.1, bert_l2norm=0.0, chr=False, cuda=True, data_dir='../data/mediqa_processed/mt_dnn_mediqa_384/', data_root='../data/', data_sort_on=False, dropout_p=0.1, dropout_w=0.0, dump_state_on=False, ema_gamma=0.995, ema_opt=0, embedding_opt=0, epochs=5, external_datasets=[], external_include_ratio=1.0, finetune=False, float_medquad=True, float_target=False, freeze_bert_first=False, freeze_layers=-1, global_grad_clipping=1.0, grad_clipping=0, have_lr_scheduler=True, hinge_lambda=1.0, init_checkpoint='../bert_models/mt_dnn_base.pt', init_config=None, init_ratio=1, label_size='3,3,2', learning_rate=5e-05, log_file='mt-dnn-train.log', log_per_updates=500, lr_gamma
# ...

# %%
# !python train.py --train_datasets mednli,rqe,mediqa --save_last --mediqa_score adjusted --chr --mediqa_score_offset -2.0 --batch_size 16 --max_seq_len 384 --data_dir ../data/mediqa_processed/mt_dnn_mediqa_384_charac/ --init_checkpoint ../bert_models/mt_dnn_base.pt --float_medquad --mtl_opt 0 --output_dir ../model_data/test_med_char_1 --epochs 5
# Out:
# Namespace(answer_att_hidden_size=128, answer_att_type='bilinear', answer_dropout_p=0.1, answer_mem_drop_p=0.1, answer_mem_type=1, answer_merge_opt=1, answer_num_turn=5, answer_opt=0, answer_relu=False, answer_rnn_type='gru', answer_sum_att_type='bilinear', answer_weight_norm_on=False, batch_size=16, batch_size_eval=16, bert_dropout_p=0.1, bert_l2norm=0.0, chr=True, cuda=True, data_dir='../data/mediqa_processed/mt_dnn_mediqa_384_charac/', data_root='../data/', data_sort_on=False, dropout_p=0.1, dropout_w=0.0, dump_state_on=False, ema_gamma=0.995, ema_opt=0, embedding_opt=0, epochs=5, external_datasets=[], external_include_ratio=1.0, finetune=False, float_medquad=True, float_target=False, freeze_bert_first=False, freeze_layers=-1, global_grad_clipping=1.0, grad_clipping=0, have_lr_scheduler=True, hinge_lambda=1.0, init_checkpoint='../bert_models/mt_dnn_base.pt', init_config=None, init_ratio=1, label_size='3,3,2', learning_rate=5e-05, log_file='mt-dnn-train.log', log_per_updates=500, lr
# ...

# %%
# !python train.py --train_datasets mednli,rqe,mediqa --save_last --mediqa_score adjusted --mediqa_score_offset -2.0 --batch_size 16 --max_seq_len 384 --data_dir ../data/mediqa_processed/mt_dnn_mediqa_384/ --float_medquad --mtl_opt 0 --output_dir ../model_data/test_bert_2_nochk --epochs 5
# Out:
# Namespace(answer_att_hidden_size=128, answer_att_type='bilinear', answer_dropout_p=0.1, answer_mem_drop_p=0.1, answer_mem_type=1, answer_merge_opt=1, answer_num_turn=5, answer_opt=0, answer_relu=False, answer_rnn_type='gru', answer_sum_att_type='bilinear', answer_weight_norm_on=False, batch_size=16, batch_size_eval=16, bert_dropout_p=0.1, bert_l2norm=0.0, chr=False, cuda=True, data_dir='../data/mediqa_processed/mt_dnn_mediqa_384/', data_root='../data/', data_sort_on=False, dropout_p=0.1, dropout_w=0.0, dump_state_on=False, ema_gamma=0.995, ema_opt=0, embedding_opt=0, epochs=5, external_datasets=[], external_include_ratio=1.0, finetune=False, float_medquad=True, float_target=False, freeze_bert_first=False, freeze_layers=-1, global_grad_clipping=1.0, grad_clipping=0, have_lr_scheduler=True, hinge_lambda=1.0, init_checkpoint='../data/bert_data/bert_model_base.pt', init_config=None, init_ratio=1, label_size='3,3,2', learning_rate=5e-05, log_file='mt-dnn-train.log', log_per_updates=500, l
# ...

# %%
# !python train.py --train_datasets mednli,rqe,mediqa --save_last --mediqa_score adjusted --mediqa_score_offset -2.0 --batch_size 16 --max_seq_len 384 --data_dir ../data/mediqa_processed/mt_dnn_mediqa_384_med/ --float_medquad --mtl_opt 0 --output_dir ../model_data/test_medical_bert_1_nochk --epochs 5 --init_config /content/drive/MyDrive/NLP/new/character-bert/pretrained-models/medical_bert
# Out:
# Namespace(answer_att_hidden_size=128, answer_att_type='bilinear', answer_dropout_p=0.1, answer_mem_drop_p=0.1, answer_mem_type=1, answer_merge_opt=1, answer_num_turn=5, answer_opt=0, answer_relu=False, answer_rnn_type='gru', answer_sum_att_type='bilinear', answer_weight_norm_on=False, batch_size=16, batch_size_eval=16, bert_dropout_p=0.1, bert_l2norm=0.0, chr=False, cuda=True, data_dir='../data/mediqa_processed/mt_dnn_mediqa_384_med/', data_root='../data/', data_sort_on=False, dropout_p=0.1, dropout_w=0.0, dump_state_on=False, ema_gamma=0.995, ema_opt=0, embedding_opt=0, epochs=5, external_datasets=[], external_include_ratio=1.0, finetune=False, float_medquad=True, float_target=False, freeze_bert_first=False, freeze_layers=-1, global_grad_clipping=1.0, grad_clipping=0, have_lr_scheduler=True, hinge_lambda=1.0, init_checkpoint='../data/bert_data/bert_model_base.pt', init_config='/content/drive/MyDrive/NLP/new/character-bert/pretrained-models/medical_bert', init_ratio=1, label_size='3,
# ...

# %%
# !python train.py --train_datasets mednli,rqe,mediqa --save_last --mediqa_score adjusted --mediqa_score_offset -2.0 --batch_size 16 --max_seq_len 384 --data_dir ../data/mediqa_processed/mt_dnn_mediqa_384_med/ --float_medquad --mtl_opt 0 --output_dir ../model_data/test_medical_bert_4_nochk --epochs 5
# Out:
# Namespace(answer_att_hidden_size=128, answer_att_type='bilinear', answer_dropout_p=0.1, answer_mem_drop_p=0.1, answer_mem_type=1, answer_merge_opt=1, answer_num_turn=5, answer_opt=0, answer_relu=False, answer_rnn_type='gru', answer_sum_att_type='bilinear', answer_weight_norm_on=False, batch_size=16, batch_size_eval=16, bert_dropout_p=0.1, bert_l2norm=0.0, chr=False, cuda=True, data_dir='../data/mediqa_processed/mt_dnn_mediqa_384_med/', data_root='../data/', data_sort_on=False, dropout_p=0.1, dropout_w=0.0, dump_state_on=False, ema_gamma=0.995, ema_opt=0, embedding_opt=0, epochs=5, external_datasets=[], external_include_ratio=1.0, finetune=False, float_medquad=True, float_target=False, freeze_bert_first=False, freeze_layers=-1, global_grad_clipping=1.0, grad_clipping=0, have_lr_scheduler=True, hinge_lambda=1.0, init_checkpoint='../data/bert_data/bert_model_base.pt', init_config=None, init_ratio=1, label_size='3,3,2', learning_rate=5e-05, log_file='mt-dnn-train.log', log_per_updates=50
# ...
